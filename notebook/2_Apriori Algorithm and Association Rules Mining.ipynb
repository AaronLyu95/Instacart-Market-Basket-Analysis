# %%
from google.cloud import bigquery
from google.oauth2 import service_account
import time
import matplotlib.pyplot as plt
import seaborn as sns
from google.cloud import bigquery_storage
import pandas as pd
import numpy as np
import plotly.graph_objects as go
import plotly.express as px
from itertools import combinations, islice
from collections import defaultdict
from tqdm import tqdm

# %% [markdown]
# # Explanation to Apriori Algorithm and Association Rules Mning

# %% [markdown]
# ## Apriori Algorithm

# %% [markdown]
# The Apriori algorithm is a popular algorithm used for association rule mining in data mining and machine learning. It aims to discover relationships or associations between items in a dataset. The algorithm follows a "bottom-up" approach and uses a breadth-first search strategy to find frequent itemsets.
#
# Here's a high-level overview of how the Apriori algorithm works:
#
# Support: The algorithm begins by calculating the support of each item in the dataset. Support represents the frequency of occurrence of an item in the dataset.
#
# Frequent Itemsets: Next, the algorithm generates a set of frequent itemsets based on a minimum support threshold set by the user. Frequent itemsets are subsets of items that meet the minimum support threshold.
#
# Candidate Generation: The algorithm uses the frequent itemsets from the previous step to generate a new set of candidate itemsets. These candidate itemsets are formed by joining the frequent itemsets with themselves.
#
# Pruning: The algorithm prunes the candidate itemsets that contain subsets that are not frequent. This step helps reduce the search space and improve the efficiency of the algorithm.
#
# Repeat: Steps 3 and 4 are repeated iteratively until no new frequent itemsets can be generated.

# %% [markdown]
# ## Association Rules Mining

# %% [markdown]
# Association rules mining is the process of discovering interesting relationships or associations among items in a dataset. It is based on the concept of conditional probability and is often used in market basket analysis, where the goal is to find associations between products frequently purchased together.
#
# Association rules are typically represented in the form of "if-then" statements. For example, if a customer buys product A, then there is a high probability that they will also buy product B.

# %% [markdown]
# ## General Exmaple

# %% [markdown]
# If a customer buys bread and milk, then there is a high probability that they will also buy butter.
# This rule implies that customers who purchase bread and milk are likely to purchase butter as well. This insight can be valuable for the grocery store in terms of product placement, promotions, and recommendations to customers.

# %% [markdown]
# ## Support

# %% [markdown]
# Support is a measure that indicates the frequency or popularity of a combination of items in a dataset. It quantifies how often a particular combination of items appears together in the dataset. Support is calculated as the ratio of the number of transactions containing the combination of items to the total number of transactions in the dataset.
#
# For example, if we have a dataset of 100 transactions, and the combination of items A and B appears together in 30 transactions, then the support for the combination (A, B) would be 30/100 = 0.3 or 30%.

# %% [markdown]
# ## Confidence (from A to B)

# %% [markdown]
# Confidence measures the reliability or strength of an association rule. Specifically, it quantifies how often an item B is purchased when item A is purchased. Confidence is calculated as the ratio of the number of transactions containing both items A and B to the number of transactions containing item A.
#
# For example, if item A appears in 50 transactions, and out of those 50 transactions, item B also appears in 30 transactions, then the confidence from A to B would be 30/50 = 0.6 or 60%.

# %% [markdown]
# ## Lift

# %% [markdown]
# Lift is a measure that assesses the strength of the association between two items (A and B) beyond what would be expected by chance. It compares the observed probability of items A and B appearing together to the expected probability of their co-occurrence if they were statistically independent. Lift is calculated as the ratio of the support for the combination of items (A, B) to the product of the individual supports of items A and B.
# A lift value greater than 1 indicates a positive association or correlation between the items. The higher the lift value, the stronger the association.
#
# For example, if the support for the combination (A, B) is 0.3, and the individual supports for items A and B are 0.5 and 0.4 respectively, then the lift would be 0.3 / (0.5 * 0.4) = 1.5.

# %% [markdown]
# # Load data from BigQuery

# %%
def bq_connector():
    key_path = "C:/Users/HEN1/Projects/Instacart_Market_Basket_Analysis/keys/plucky-mile-327121-255163f80b63.json"
    credentials = service_account.Credentials.from_service_account_file(
        key_path, scopes=["https://www.googleapis.com/auth/cloud-platform"],
    )

    bqclient = bigquery.Client(credentials=credentials, project=credentials.project_id,)
    bqstorageclient = bigquery_storage.BigQueryReadClient(credentials=credentials)
    return bqclient, bqstorageclient

def bq_full_table_df(bqclient, bqstorageclient, table_name):
    sql_query = f"SELECT * FROM instacart.{table_name}"
    query_job = bqclient.query(sql_query)
    time.sleep(30)
    count =0 
    while query_job.state !='DONE':
        print("NOT DONE")
        if query_job.state =='PENDING':
            print(f"job from {table_name} is pending")
            break
        if query_job.state =='RUNNING':
            print(f"job from {table_name} is running")
            print(query_job.result())
            time.sleep(60)
            query_job.reload()
            time.sleep(10)
            count += 1
            if count>3:
                break
        else:
            print("may meet an error")
            break
    if query_job.state == 'DONE':
        print(f"successfully finished getting data from {table_name} table")
        df = query_job.to_dataframe(bqstorage_client=bqstorageclient, 
                                    progress_bar_type='tqdm_notebook',)
        print("successfully transferred to df")
        time.sleep(3)
    else:
        print("error")

    return df

# %%
bqclient, bqstorageclient = bq_connector()

# %%
aisles = bq_full_table_df(bqclient, bqstorageclient, 'aisles')
time.sleep(3)
# Out:
# successfully finished getting data from aisles table
# Query is running:   0%|          |
# Downloading:   0%|          |
# successfully transferred to df

# %%
departments = bq_full_table_df(bqclient, bqstorageclient, 'departments')
time.sleep(60)
# Out:
# successfully finished getting data from departments table
# Query is running:   0%|          |
# Downloading:   0%|          |
# successfully transferred to df

# %%
orders = bq_full_table_df(bqclient, bqstorageclient, 'orders')
time.sleep(60)
# Out:
# NOT DONE
# job from orders is running
# <google.cloud.bigquery.table.RowIterator object at 0x0000025CC6B07100>
# successfully finished getting data from orders table
# Query is running:   0%|          |
# Downloading:   0%|          |
# successfully transferred to df

# %%
products = bq_full_table_df(bqclient, bqstorageclient, 'products')
time.sleep(60)
# Out:
# successfully finished getting data from products table
# Query is running:   0%|          |
# Downloading:   0%|          |
# successfully transferred to df

# %%
order_products_prior = bq_full_table_df(bqclient, bqstorageclient, 'order_products_prior')
time.sleep(60)
# Out:
# NOT DONE
# job from order_products_prior is running
# <google.cloud.bigquery.table.RowIterator object at 0x000001D0BEE14640>
# successfully finished getting data from order_products_prior table
# Query is running:   0%|          |
# Downloading:   0%|          |
# successfully transferred to df

# %%
order_products_train = bq_full_table_df(bqclient, bqstorageclient, 'order_products_train')
# Out:
# NOT DONE
# job from order_products_train is running
# <google.cloud.bigquery.table.RowIterator object at 0x0000025CC6AE9220>
# successfully finished getting data from order_products_train table
# Query is running:   0%|          |
# Downloading:   0%|          |
# successfully transferred to df

# %% [markdown]
# # Extract data from dataset

# %%
order_products_prior[['order_id', 'product_id']].head(20)
# Out:
#     order_id  product_id
# 0    1091226       27735
# 1    1679699        1100
# 2    3172993       31404
# 3     490071        6187
# 4     400235        4809
# 5     583860       24184
# 6    3092797       37935
# 7     155898        2245
# 8     241827       33754
# 9    1495286       39275
# 10   1926282        3850
# 11   2041145       24004
# 12    536935       44560
# 13   1838605       37807
# 14    699367       47626
# 15   3076117       13457
# 16   1283874       49325
# 17   1627942       26209
# 18    470033        3957
# 19    895793       49683

# %%
transactions = order_products_prior.groupby('order_id')['product_id'].apply(list).tolist()

# %%
def generate_itemsets(transactions):
    itemsets = []
    num_transactions = len(transactions)

    # Generate all possible itemsets of length 2
    for transaction in tqdm(transactions, desc="Generating Itemsets"):
        pairs = list(combinations(transaction, 2))
        itemsets.extend(pairs)

    # Create a DataFrame from itemsets
    itemsets_df = pd.DataFrame(itemsets, columns=['itemA_id', 'itemB_id'])
    itemsets_df['count'] = 1

    return itemsets_df


def analyze_itemsets(itemsets_df, transactions):
    num_transactions = len(transactions)

    # Calculate supportAB for each itemset
    itemsets_df_groupby = itemsets_df.groupby(['itemA_id', 'itemB_id'], as_index=False)['count'].sum()
    itemsets_df_groupby['supportAB'] = itemsets_df_groupby['count'] / num_transactions
    print("Finished calculate supportAB")
    itemsets_df_groupby.drop(['count'], axis=1, inplace=True)

    # Sort itemsets based on supportAB in descending order
    itemsets_df_groupby.sort_values('supportAB', ascending=False, inplace=True)

    # Create a DataFrame to store the item counts for single items
    single_item_counts = pd.Series(transactions).explode().value_counts().reset_index()
    single_item_counts.columns = ['item_id', 'count']

    # Calculate supportA and supportB for the top itemsets
    output = pd.merge(itemsets_df_groupby, single_item_counts, left_on='itemA_id', right_on='item_id', how='left')
    output['supportA'] = output['count'] / num_transactions
    output.drop(['item_id', 'count'], axis=1, inplace=True)

    output = pd.merge(output, single_item_counts, left_on='itemB_id', right_on='item_id', how='left')
    output['supportB'] = output['count'] / num_transactions
    output.drop(['item_id', 'count'], axis=1, inplace=True)

    # Calculate confidenceAtoB, confidenceBtoA, and lift for the top itemsets
    output['confidenceAtoB'] = output['supportAB'] / output['supportA']
    output['confidenceBtoA'] = output['supportAB'] / output['supportB']
    output['lift'] = output['supportAB'] / (output['supportA'] * output['supportB'])

    return output

# %%
# Generate itemsets
itemsets_df = generate_itemsets(transactions)
# Out:
# Generating Itemsets: 100%|██████████| 3214874/3214874 [00:24<00:00, 129648.85it/s]

# %%
# Analyze top K itemsets and store the results in a DataFrame
top_itemsets_df = analyze_itemsets(itemsets_df, transactions)
# Out:
# Finished calculate supportAB

# %%
top_itemsets_df = top_itemsets_df.merge(products[['product_id', 'product_name']], left_on='itemA_id', right_on='product_id', how='left').rename(columns={'product_name': 'productA_name'})
top_itemsets_df = top_itemsets_df.merge(products[['product_id', 'product_name']], left_on='itemB_id', right_on='product_id', how='left').rename(columns={'product_name': 'productB_name'})

# %%
top_itemsets_df = top_itemsets_df.drop(columns=['product_id_x', 'product_id_y'])

# %%
pd.set_option('display.max_rows', 200)

# %%
top_itemsets_df.head(100)
# Out:
#     itemA_id  itemB_id  supportAB  supportA  supportB  confidenceAtoB  \
# 0      13176     47209   0.009736  0.118030  0.066436        0.082488
# 1      47209     13176   0.009655  0.066436  0.118030        0.145334
# 2      13176     21137   0.009602  0.118030  0.082331        0.081352
# 3      21137     13176   0.009568  0.082331  0.118030        0.116211
# 4      24852     21137   0.008838  0.146993  0.082331        0.060123
# 5      21137     24852   0.008630  0.082331  0.146993        0.104820
# 6      24852     47766   0.008329  0.146993  0.054999        0.056663
# 7      47766     24852   0.008280  0.054999  0.146993        0.150542
# 8      24852     21903   0.008035  0.146993  0.075251        0.054663
# 9      21903     24852   0.007951  0.075251  0.146993        0.105667
# 10     13176     21903   0.007904  0.118030  0.075251        0.066968
# 11     21903     13176   0.007764  0.075251  0.118030        0.103178
# 12     24852     16797   0.006566  0.146993  0.044466        0.044669
# 13     24852     47626   0.006485  0.146993  0.047485        0.044115
# 14     21137     47209   0.006376  0.082331  0.066436        0.077447
# 15     13176     27966   0.006369  0.118030  0.042632        0.053957
# 16     47209     21137   0.006313  0.066436  0.082331        0.095021
# 17     16797     24852   0.006259  0.044466  0.146993        0.140769
# 18     47626     24852   0.006231  0.047485  0.146993        0.131229
# 19     27966     13176   0.006230  0.042632  0.118030        0.146136
# 20     21137     21903   0.005964  0.082331  0.075251        0.072434
# 21     21903     21137   0.005898  0.075251  0.082331        0.078381
# 22     21903     47209   0.005433  0.075251  0.066436        0.072193
# 23     47209     21903   0.005424  0.066436  0.075251        0.081635
# 24     24852     28204   0.005361  0.146993  0.027880        0.036471
# 25     21137     27966   0.005299  0.082331  0.042632        0.064360
# 26     27966     21137   0.005234  0.042632  0.082331        0.122781
# 27     28204     24852   0.005197  0.027880  0.146993        0.186407
# 28     24852     49683   0.005089  0.146993  0.030270        0.034620
# 29     24852     26209   0.005066  0.146993  0.043743        0.034461
# 30     24852     27845   0.004931  0.146993  0.042896        0.033545
# 31     27845     24852   0.004911  0.042896  0.146993        0.114492
# 32     24852     47209   0.004901  0.146993  0.066436        0.033339
# 33     49683     24852   0.004895  0.030270  0.146993        0.161712
# 34     26209     24852   0.004817  0.043743  0.146993        0.110128
# 35     47209     24852   0.004811  0.066436  0.146993        0.072416
# 36     21903     47766   0.004806  0.075251  0.054999        0.063868
# 37     47766     21903   0.004802  0.054999  0.075251        0.087312
# 38     24852     45066   0.004494  0.146993  0.024812        0.030576
# 39     45066     24852   0.004342  0.024812  0.146993        0.174993
# 40     47626     26209   0.004288  0.047485  0.043743        0.090307
# 41     26209     47626   0.004236  0.043743  0.047485        0.096831
# 42     27845     13176   0.004145  0.042896  0.118030        0.096632
# 43     13176     27845   0.004092  0.118030  0.042896        0.034669
# 44     47209     27966   0.004014  0.066436  0.042632        0.060417
# 45     27966     47209   0.004009  0.042632  0.066436        0.094041
# 46     24852      4920   0.003921  0.146993  0.025721        0.026674
# 47     13176     22935   0.003890  0.118030  0.035282        0.032961
# 48     47766     47626   0.003842  0.054999  0.047485        0.069847
# 49     21137     47766   0.003767  0.082331  0.054999        0.045757
# 50     47626     47766   0.003753  0.047485  0.054999        0.079046
# 51     22935     13176   0.003753  0.035282  0.118030        0.106387
# 52     21137     39275   0.003749  0.082331  0.031124        0.045537
# 53     21137     27845   0.003748  0.082331  0.042896        0.045519
# 54     13176      8277   0.003730  0.118030  0.026446        0.031598
# 55      4920     24852   0.003729  0.025721  0.146993        0.144989
# 56     47766     21137   0.003693  0.054999  0.082331        0.067149
# 57     13176     19057   0.003661  0.118030  0.023380        0.031019
# 58     27845     21137   0.003660  0.042896  0.082331        0.085312
# 59      8277     13176   0.003641  0.026446  0.118030        0.137685
# 60     39275     21137   0.003640  0.031124  0.082331        0.116960
# 61     19057     13176   0.003606  0.023380  0.118030        0.154247
# 62     24852     27966   0.003598  0.146993  0.042632        0.024475
# 63     13176     47766   0.003588  0.118030  0.054999        0.030397
# 64     13176     45007   0.003586  0.118030  0.032606        0.030386
# 65     21903     47626   0.003585  0.075251  0.047485        0.047640
# 66     13176      5876   0.003536  0.118030  0.027294        0.029962
# 67     47766     13176   0.003533  0.054999  0.118030        0.064231
# 68     27966     24852   0.003523  0.042632  0.146993        0.082637
# 69     47626     21903   0.003510  0.047485  0.075251        0.073911
# 70     47766     26209   0.003501  0.054999  0.043743        0.063648
# 71     13176     39275   0.003480  0.118030  0.031124        0.029487
# 72     22935     24964   0.003459  0.035282  0.034147        0.098046
# 73     45007     13176   0.003453  0.032606  0.118030        0.105912
# 74      5876     13176   0.003426  0.027294  0.118030        0.125521
# 75     13176     30391   0.003416  0.118030  0.025006        0.028945
# 76     24852      4605   0.003414  0.146993  0.022759        0.023226
# 77     24964     22935   0.003407  0.034147  0.035282        0.099765
# 78     47209      5876   0.003388  0.066436  0.027294        0.050992
# 79     13176     24964   0.003362  0.118030  0.034147        0.028489
# 80     26209     47766   0.003346  0.043743  0.054999        0.076486
# 81     39275     13176   0.003322  0.031124  0.118030        0.106726
# 82     13176     26209   0.003315  0.118030  0.043743        0.028088
# 83     21903     24964   0.003313  0.075251  0.034147        0.044031
# 84     30391     13176   0.003282  0.025006  0.118030        0.131244
# 85     24964     13176   0.003269  0.034147  0.118030        0.095720
# 86     21903     26209   0.003242  0.075251  0.043743        0.043080
# 87      5876     47209   0.003221  0.027294  0.066436        0.118011
# 88     26209     21903   0.003221  0.043743  0.075251        0.073627
# 89     24964     21903   0.003218  0.034147  0.075251        0.094227
# 90     21903     45007   0.003205  0.075251  0.032606        0.042597
# 91     26209     13176   0.003180  0.043743  0.118030        0.072696
# 92      4605     24852   0.003170  0.022759  0.146993        0.139298
# 93     47209     26209   0.003150  0.066436  0.043743        0.047419
# 94     45007     21903   0.003145  0.032606  0.075251        0.096448
# 95     24852     45007   0.003109  0.146993  0.032606        0.021153
# 96     47209     22935   0.003107  0.066436  0.035282        0.046768
# 97     21903     22935   0.003094  0.075251  0.035282        0.041117
# 98     22935     47209   0.003091  0.035282  0.066436        0.087617
# 99     26209     47209   0.003080  0.043743  0.066436        0.070413
#
#     confidenceBtoA      lift                         productA_name  \
# 0         0.146547  1.241609                Bag of Organic Bananas
# 1         0.081805  1.231335                  Organic Hass Avocado
# 2         0.116626  0.988111                Bag of Organic Bananas
# 3         0.081062  0.984590                  Organic Strawberries
# 4         0.107344  0.730261                                Banana
# 5         0.058709  0.713092                  Organic Strawberries
# 6         0.151441  1.030256                                Banana
# 7         0.056327  1.024139                       Organic Avocado
# 8         0.106779  0.726418                                Banana
# 9         0.054094  0.718854                  Organic Baby Spinach
# 10        0.105038  0.889934                Bag of Organic Bananas
# 11        0.065782  0.874174                  Organic Baby Spinach
# 12        0.147666  1.004576                                Banana
# 13        0.136561  0.929029                                Banana
# 14        0.095976  1.165740                  Organic Strawberries
# 15        0.149383  1.265642                Bag of Organic Bananas
# 16        0.076677  1.154139                  Organic Hass Avocado
# 17        0.042583  0.957652                          Strawberries
# 18        0.042392  0.892754                           Large Lemon
# 19        0.052784  1.238133                   Organic Raspberries
# 20        0.079249  0.962569                  Organic Strawberries
# 21        0.071640  0.952025                  Organic Baby Spinach
# 22        0.081771  1.086651                  Organic Baby Spinach
# 23        0.072073  1.084847                  Organic Hass Avocado
# 24        0.192286  1.308129                                Banana
# 25        0.124291  1.509659                  Organic Strawberries
# 26        0.063578  1.491314                   Organic Raspberries
# 27        0.035356  1.268130                    Organic Fuji Apple
# 28        0.168114  1.143684                                Banana
# 29        0.115803  0.787810                                Banana
# 30        0.114949  0.781999                                Banana
# 31        0.033411  0.778892                    Organic Whole Milk
# 32        0.073765  0.501825                                Banana
# 33        0.033301  1.100131                        Cucumber Kirby
# 34        0.032772  0.749206                                 Limes
# 35        0.032730  0.492651                  Organic Hass Avocado
# 36        0.087385  1.161256                  Organic Baby Spinach
# 37        0.063814  1.160279                       Organic Avocado
# 38        0.181136  1.232270                                Banana
# 39        0.029539  1.190481                      Honeycrisp Apple
# 40        0.098032  2.064509                           Large Lemon
# 41        0.089200  2.039201                                 Limes
# 42        0.035119  0.818708                    Organic Whole Milk
# 43        0.095392  0.808203                Bag of Organic Bananas
# 44        0.094151  1.417158                  Organic Hass Avocado
# 45        0.060346  1.415511                   Organic Raspberries
# 46        0.152439  1.037045                                Banana
# 47        0.110266  0.934222                Bag of Organic Bananas
# 48        0.080900  1.470940                       Organic Avocado
# 49        0.068495  0.831953                  Organic Strawberries
# 50        0.068246  1.437234                           Large Lemon
# 51        0.031801  0.901355                  Organic Yellow Onion
# 52        0.120458  1.463095                  Organic Strawberries
# 53        0.087364  1.061140                  Organic Strawberries
# 54        0.141026  1.194834                Bag of Organic Bananas
# 55        0.025370  0.986365                   Seedless Red Grapes
# 56        0.044857  0.815604                       Organic Avocado
# 57        0.156589  1.326692                Bag of Organic Bananas
# 58        0.044449  1.036215                    Organic Whole Milk
# 59        0.030850  1.166532              Apple Honeycrisp Organic
# 60        0.044215  1.420609                   Organic Blueberries
# 61        0.030555  1.306854  Organic Large Extra Fancy Fuji Apple
# 62        0.084388  0.574096                                Banana
# 63        0.065232  0.552676                Bag of Organic Bananas
# 64        0.109995  0.931927                Bag of Organic Bananas
# 65        0.075496  1.003263                  Organic Baby Spinach
# 66        0.129567  1.097752                Bag of Organic Bananas
# 67        0.029930  0.544194                       Organic Avocado
# 68        0.023967  0.562183                   Organic Raspberries
# 69        0.046639  0.982196                           Large Lemon
# 70        0.080027  1.455067                       Organic Avocado
# 71        0.111823  0.947415                Bag of Organic Bananas
# 72        0.101304  2.871309                  Organic Yellow Onion
# 73        0.029258  0.897334                      Organic Zucchini
# 74        0.029026  1.063475                         Organic Lemon
# 75        0.136618  1.157491                Bag of Organic Bananas
# 76        0.150013  1.020543                                Banana
# 77        0.096556  2.827675                        Organic Garlic
# 78        0.124120  1.868253                  Organic Hass Avocado
# 79        0.098471  0.834295                Bag of Organic Bananas
# 80        0.060832  1.390679                                 Limes
# 81        0.028143  0.904231                   Organic Blueberries
# 82        0.075789  0.642120                Bag of Organic Bananas
# 83        0.097032  1.289455                  Organic Baby Spinach
# 84        0.027806  1.111963                      Organic Cucumber
# 85        0.027693  0.810987                        Organic Garlic
# 86        0.074111  0.984856                  Organic Baby Spinach
# 87        0.048482  1.776307                         Organic Lemon
# 88        0.042799  0.978430                                 Limes
# 89        0.042758  1.252171                        Organic Garlic
# 90        0.098309  1.306417                  Organic Baby Spinach
# 91        0.026942  0.615913                                 Limes
# 92        0.021567  0.947647                         Yellow Onions
# 93        0.072020  1.084052                  Organic Hass Avocado
# 94        0.041791  1.281696                      Organic Zucchini
# 95        0.095361  0.648742                                Banana
# 96        0.088066  1.325576                  Organic Hass Avocado
# 97        0.087696  1.165386                  Organic Baby Spinach
# 98        0.046530  1.318808                  Organic Yellow Onion
# 99        0.046361  1.059862                                 Limes
#
#                            productB_name
# 0                   Organic Hass Avocado
# 1                 Bag of Organic Bananas
# 2                   Organic Strawberries
# 3                 Bag of Organic Bananas
# 4                   Organic Strawberries
# 5                                 Banana
# 6                        Organic Avocado
# 7                                 Banana
# 8                   Organic Baby Spinach
# 9                                 Banana
# 10                  Organic Baby Spinach
# 11                Bag of Organic Bananas
# 12                          Strawberries
# 13                           Large Lemon
# 14                  Organic Hass Avocado
# 15                   Organic Raspberries
# 16                  Organic Strawberries
# 17                                Banana
# 18                                Banana
# 19                Bag of Organic Bananas
# 20                  Organic Baby Spinach
# 21                  Organic Strawberries
# 22                  Organic Hass Avocado
# 23                  Organic Baby Spinach
# 24                    Organic Fuji Apple
# 25                   Organic Raspberries
# 26                  Organic Strawberries
# 27                                Banana
# 28                        Cucumber Kirby
# 29                                 Limes
# 30                    Organic Whole Milk
# 31                                Banana
# 32                  Organic Hass Avocado
# 33                                Banana
# 34                                Banana
# 35                                Banana
# 36                       Organic Avocado
# 37                  Organic Baby Spinach
# 38                      Honeycrisp Apple
# 39                                Banana
# 40                                 Limes
# 41                           Large Lemon
# 42                Bag of Organic Bananas
# 43                    Organic Whole Milk
# 44                   Organic Raspberries
# 45                  Organic Hass Avocado
# 46                   Seedless Red Grapes
# 47                  Organic Yellow Onion
# 48                           Large Lemon
# 49                       Organic Avocado
# 50                       Organic Avocado
# 51                Bag of Organic Bananas
# 52                   Organic Blueberries
# 53                    Organic Whole Milk
# 54              Apple Honeycrisp Organic
# 55                                Banana
# 56                  Organic Strawberries
# 57  Organic Large Extra Fancy Fuji Apple
# 58                  Organic Strawberries
# 59                Bag of Organic Bananas
# 60                  Organic Strawberries
# 61                Bag of Organic Bananas
# 62                   Organic Raspberries
# 63                       Organic Avocado
# 64                      Organic Zucchini
# 65                           Large Lemon
# 66                         Organic Lemon
# 67                Bag of Organic Bananas
# 68                                Banana
# 69                  Organic Baby Spinach
# 70                                 Limes
# 71                   Organic Blueberries
# 72                        Organic Garlic
# 73                Bag of Organic Bananas
# 74                Bag of Organic Bananas
# 75                      Organic Cucumber
# 76                         Yellow Onions
# 77                  Organic Yellow Onion
# 78                         Organic Lemon
# 79                        Organic Garlic
# 80                       Organic Avocado
# 81                Bag of Organic Bananas
# 82                                 Limes
# 83                        Organic Garlic
# 84                Bag of Organic Bananas
# 85                Bag of Organic Bananas
# 86                                 Limes
# 87                  Organic Hass Avocado
# 88                  Organic Baby Spinach
# 89                  Organic Baby Spinach
# 90                      Organic Zucchini
# 91                Bag of Organic Bananas
# 92                                Banana
# 93                                 Limes
# 94                  Organic Baby Spinach
# 95                      Organic Zucchini
# 96                  Organic Yellow Onion
# 97                  Organic Yellow Onion
# 98                  Organic Hass Avocado
# 99                  Organic Hass Avocado

# %%
top_itemsets_df[(top_itemsets_df['productA_name']=='Organic Strawberries') & (top_itemsets_df['supportAB'] > 0.0005)].sort_values(by='lift', ascending=False)
# Out:
#       itemA_id  itemB_id  supportAB  supportA  supportB  confidenceAtoB  \
# 1854     21137     19706   0.000757  0.082331  0.004075        0.009192
# 835      21137     38159   0.001182  0.082331  0.006626        0.014357
# 1129     21137     38777   0.001004  0.082331  0.006764        0.012196
# 2292     21137     26790   0.000665  0.082331  0.005017        0.008081
# 1754     21137     26940   0.000781  0.082331  0.005999        0.009487
# 1749     21137     17600   0.000784  0.082331  0.006100        0.009521
# 285      21137     39928   0.001997  0.082331  0.015597        0.024259
# 554      21137     43122   0.001482  0.082331  0.011729        0.018003
# 25       21137     27966   0.005299  0.082331  0.042632        0.064360
# 3153     21137     11782   0.000559  0.082331  0.004547        0.006789
# 1350     21137       260   0.000911  0.082331  0.007434        0.011070
# 2404     21137     45633   0.000649  0.082331  0.005331        0.007881
# 2965     21137     25340   0.000578  0.082331  0.004759        0.007016
# 52       21137     39275   0.003749  0.082331  0.031124        0.045537
# 242      21137     22035   0.002128  0.082331  0.018562        0.025842
# 1137     21137     22963   0.001001  0.082331  0.008829        0.012162
# 2668     21137     13629   0.000612  0.082331  0.005419        0.007435
# 2395     21137     26283   0.000650  0.082331  0.005881        0.007892
# 3011     21137     34448   0.000573  0.082331  0.005241        0.006959
# 437      21137     22825   0.001653  0.082331  0.015215        0.020073
# 2595     21137     18370   0.000622  0.082331  0.005739        0.007552
# 1683     21137     36695   0.000800  0.082331  0.007432        0.009717
# 307      21137     10749   0.001909  0.082331  0.017881        0.023190
# 2798     21137     10132   0.000597  0.082331  0.005611        0.007246
# 1093     21137     42828   0.001023  0.082331  0.009702        0.012422
# 735      21137      9839   0.001268  0.082331  0.012044        0.015403
# 933      21137      7781   0.001119  0.082331  0.010641        0.013594
# 2790     21137      3952   0.000598  0.082331  0.005705        0.007265
# 135      21137     30391   0.002616  0.082331  0.025006        0.031770
# 1705     21137      5212   0.000794  0.082331  0.007631        0.009646
# 1873     21137     43768   0.000752  0.082331  0.007275        0.009132
# 171      21137     19057   0.002412  0.082331  0.023380        0.029295
# 295      21137     26604   0.001964  0.082331  0.019206        0.023851
# 3144     21137     43713   0.000560  0.082331  0.005611        0.006797
# 963      21137     38689   0.001105  0.082331  0.011093        0.013424
# 831      21137     46906   0.001184  0.082331  0.012122        0.014379
# 3142     21137     37158   0.000560  0.082331  0.005786        0.006801
# 3728     21137     17461   0.000504  0.082331  0.005231        0.006124
# 14       21137     47209   0.006376  0.082331  0.066436        0.077447
# 145      21137      8277   0.002529  0.082331  0.026446        0.030720
# 2788     21137     14678   0.000598  0.082331  0.006292        0.007269
# 2569     21137     46969   0.000625  0.082331  0.006666        0.007594
# 159      21137     40706   0.002453  0.082331  0.026208        0.029790
# 324      21137     41950   0.001868  0.082331  0.019997        0.022688
# 871      21137     18465   0.001156  0.082331  0.012456        0.014036
# 2950     21137     29447   0.000580  0.082331  0.006283        0.007042
# 1331     21137     30233   0.000916  0.082331  0.009986        0.011123
# 261      21137     37646   0.002073  0.082331  0.022659        0.025185
# 1810     21137     21405   0.000767  0.082331  0.008469        0.009321
# 2781     21137      7948   0.000599  0.082331  0.006690        0.007280
# 520      21137     43961   0.001529  0.082331  0.017223        0.018566
# 1392     21137     19678   0.000895  0.082331  0.010120        0.010866
# 904      21137     27344   0.001136  0.082331  0.012900        0.013801
# 53       21137     27845   0.003748  0.082331  0.042896        0.045519
# 1161     21137      4799   0.000987  0.082331  0.011311        0.011984
# 255      21137     42265   0.002086  0.082331  0.023919        0.025336
# 182      21137      5876   0.002380  0.082331  0.027294        0.028906
# 3269     21137     16349   0.000546  0.082331  0.006289        0.006627
# 3341     21137     23375   0.000539  0.082331  0.006220        0.006544
# 3325     21137     44422   0.000540  0.082331  0.006265        0.006559
# 2036     21137     31343   0.000715  0.082331  0.008329        0.008690
# 218      21137      4920   0.002209  0.082331  0.025721        0.026832
# 2071     21137     36011   0.000708  0.082331  0.008271        0.008595
# 1562     21137     24489   0.000835  0.082331  0.009781        0.010140
# 917      21137      8174   0.001126  0.082331  0.013289        0.013681
# 822      21137     33731   0.001190  0.082331  0.014071        0.014459
# 322      21137     30489   0.001870  0.082331  0.022183        0.022718
# 1346     21137     41220   0.000912  0.082331  0.010848        0.011077
# 516      21137     39877   0.001532  0.082331  0.018283        0.018607
# 3576     21137     13984   0.000514  0.082331  0.006142        0.006249
# 2119     21137     38293   0.000696  0.082331  0.008312        0.008452
# 3482     21137     28289   0.000524  0.082331  0.006287        0.006359
# 1608     21137     34243   0.000818  0.082331  0.009889        0.009933
# 3382     21137     47672   0.000534  0.082331  0.006462        0.006487
# 2725     21137     24830   0.000606  0.082331  0.007354        0.007356
# 2022     21137      1463   0.000717  0.082331  0.008707        0.008709
# 3750     21137     32864   0.000503  0.082331  0.006109        0.006105
# 1828     21137     17948   0.000763  0.082331  0.009302        0.009268
# 2919     21137     18362   0.000584  0.082331  0.007156        0.007095
# 2522     21137     13870   0.000632  0.082331  0.007761        0.007673
# 1219     21137     27156   0.000960  0.082331  0.011820        0.011655
# 3        21137     13176   0.009568  0.082331  0.118030        0.116211
# 821      21137      5785   0.001191  0.082331  0.014881        0.014470
# 1672     21137     40604   0.000802  0.082331  0.010063        0.009740
# 416      21137     44359   0.001685  0.082331  0.021180        0.020466
# 20       21137     21903   0.005964  0.082331  0.075251        0.072434
# 720      21137     48679   0.001279  0.082331  0.016156        0.015539
# 2346     21137     42701   0.000657  0.082331  0.008302        0.007979
# 1646     21137     20995   0.000809  0.082331  0.010230        0.009827
# 2558     21137     32655   0.000626  0.082331  0.007939        0.007609
# 374      21137     27104   0.001746  0.082331  0.022267        0.021203
# 1991     21137     33754   0.000725  0.082331  0.009298        0.008807
# 1226     21137     28199   0.000957  0.082331  0.012388        0.011625
# 2095     21137     26369   0.000701  0.082331  0.009113        0.008512
# 637      21137     35951   0.001384  0.082331  0.018008        0.016809
# 481      21137     46979   0.001591  0.082331  0.020929        0.019321
# 486      21137     28985   0.001585  0.082331  0.020980        0.019253
# 2676     21137     11777   0.000612  0.082331  0.008156        0.007428
# 413      21137     21616   0.001693  0.082331  0.022654        0.020568
# 715      21137     21938   0.001285  0.082331  0.017259        0.015607
# 168      21137     45007   0.002422  0.082331  0.032606        0.029420
# 134      21137     22935   0.002617  0.082331  0.035282        0.031789
# 331      21137     45066   0.001840  0.082331  0.024812        0.022347
# 2729     21137     39475   0.000605  0.082331  0.008225        0.007352
# 150      21137     24964   0.002491  0.082331  0.034147        0.030255
# 3165     21137     18531   0.000557  0.082331  0.007672        0.006770
# 3352     21137     10246   0.000537  0.082331  0.007411        0.006525
# 1659     21137     16759   0.000805  0.082331  0.011142        0.009778
# 3434     21137     38383   0.000529  0.082331  0.007354        0.006423
# 2800     21137     43789   0.000596  0.082331  0.008295        0.007239
# 664      21137     34126   0.001344  0.082331  0.018856        0.016325
# 1390     21137     11520   0.000895  0.082331  0.012559        0.010870
# 1549     21137      3957   0.000840  0.082331  0.011812        0.010208
# 876      21137     46667   0.001152  0.082331  0.016202        0.013990
# 562      21137      8518   0.001472  0.082331  0.020836        0.017874
# 687      21137      5077   0.001328  0.082331  0.018917        0.016125
# 3189     21137      2295   0.000555  0.082331  0.007919        0.006740
# 2149     21137     37687   0.000689  0.082331  0.009882        0.008372
# 1287     21137     27521   0.000932  0.082331  0.013396        0.011319
# 502      21137     17794   0.001559  0.082331  0.022625        0.018932
# 104      21137     26209   0.003007  0.082331  0.043743        0.036523
# 3394     21137     46802   0.000532  0.082331  0.007761        0.006464
# 49       21137     47766   0.003767  0.082331  0.054999        0.045757
# 583      21137     31717   0.001447  0.082331  0.021626        0.017576
# 2645     21137      5479   0.000616  0.082331  0.009623        0.007481
# 3419     21137     41844   0.000530  0.082331  0.008318        0.006434
# 1572     21137      8424   0.000828  0.082331  0.013078        0.010061
# 1187     21137     24838   0.000975  0.082331  0.015419        0.011844
# 2844     21137     42768   0.000591  0.082331  0.009349        0.007178
# 312      21137     49683   0.001902  0.082331  0.030270        0.023107
# 2312     21137     33000   0.000662  0.082331  0.010547        0.008044
# 3094     21137     42585   0.000565  0.082331  0.009059        0.006865
# 3774     21137     32689   0.000501  0.082331  0.008079        0.006090
# 951      21137     43352   0.001110  0.082331  0.017929        0.013488
# 3380     21137      8021   0.000534  0.082331  0.008667        0.006491
# 1895     21137     15290   0.000747  0.082331  0.012190        0.009071
# 1224     21137     25890   0.000958  0.082331  0.015640        0.011633
# 586      21137     49235   0.001443  0.082331  0.023752        0.017523
# 3106     21137     16185   0.000564  0.082331  0.009385        0.006853
# 3655     21137     25659   0.000509  0.082331  0.008478        0.006185
# 725      21137     27086   0.001277  0.082331  0.021530        0.015505
# 2379     21137     42736   0.000651  0.082331  0.011094        0.007911
# 5        21137     24852   0.008630  0.082331  0.146993        0.104820
# 1151     21137     34969   0.000992  0.082331  0.016924        0.012048
# 1403     21137      5450   0.000892  0.082331  0.015248        0.010839
# 1344     21137     31506   0.000912  0.082331  0.015632        0.011081
# 3451     21137     14992   0.000527  0.082331  0.009042        0.006404
# 1135     21137     24184   0.001002  0.082331  0.017195        0.012169
# 3705     21137     28849   0.000505  0.082331  0.008686        0.006139
# 1196     21137      9076   0.000971  0.082331  0.017402        0.011795
# 138      21137     47626   0.002583  0.082331  0.047485        0.031377
# 1748     21137     35221   0.000784  0.082331  0.014478        0.009525
# 1539     21137     12341   0.000843  0.082331  0.015621        0.010239
# 534      21137     28204   0.001503  0.082331  0.027880        0.018260
# 2838     21137     41787   0.000592  0.082331  0.011015        0.007190
# 754      21137     44632   0.001251  0.082331  0.023605        0.015199
# 2241     21137     20114   0.000676  0.082331  0.013239        0.008210
# 2986     21137     34358   0.000575  0.082331  0.011390        0.006989
# 2405     21137     44142   0.000649  0.082331  0.013378        0.007881
# 976      21137      4605   0.001093  0.082331  0.022759        0.013280
# 2484     21137     28842   0.000638  0.082331  0.014162        0.007749
# 2805     21137     33198   0.000596  0.082331  0.013355        0.007235
# 1865     21137     19660   0.000753  0.082331  0.017446        0.009143
#
#       confidenceBtoA      lift         productA_name  \
# 1854        0.185711  2.255670  Organic Strawberries
# 835         0.178395  2.166813  Organic Strawberries
# 1129        0.148448  1.803068  Organic Strawberries
# 2292        0.132618  1.610799  Organic Strawberries
# 1754        0.130198  1.581403  Organic Strawberries
# 1749        0.128499  1.560769  Organic Strawberries
# 285         0.128059  1.555420  Organic Strawberries
# 554         0.126372  1.534936  Organic Strawberries
# 25          0.124291  1.509659  Organic Strawberries
# 3153        0.122931  1.493131  Organic Strawberries
# 1350        0.122594  1.489044  Organic Strawberries
# 2404        0.121704  1.478228  Organic Strawberries
# 2965        0.121365  1.474110  Organic Strawberries
# 52          0.120458  1.463095  Organic Strawberries
# 242         0.114619  1.392177  Organic Strawberries
# 1137        0.113409  1.377480  Organic Strawberries
# 2668        0.112954  1.371956  Organic Strawberries
# 2395        0.110494  1.342075  Organic Strawberries
# 3011        0.109318  1.327785  Organic Strawberries
# 437         0.108617  1.319276  Organic Strawberries
# 2595        0.108353  1.316067  Organic Strawberries
# 1683        0.107651  1.307544  Organic Strawberries
# 307         0.106776  1.296911  Organic Strawberries
# 2798        0.106319  1.291368  Organic Strawberries
# 1093        0.105412  1.280343  Organic Strawberries
# 735         0.105294  1.278920  Organic Strawberries
# 933         0.105177  1.277493  Organic Strawberries
# 2790        0.104847  1.273486  Organic Strawberries
# 135         0.104600  1.270485  Organic Strawberries
# 1705        0.104060  1.263922  Organic Strawberries
# 1873        0.103344  1.255225  Organic Strawberries
# 171         0.103160  1.252991  Organic Strawberries
# 295         0.102241  1.241838  Organic Strawberries
# 3144        0.099723  1.211247  Organic Strawberries
# 963         0.099627  1.210083  Organic Strawberries
# 831         0.097662  1.186220  Organic Strawberries
# 3142        0.096764  1.175306  Organic Strawberries
# 3728        0.096396  1.170842  Organic Strawberries
# 14          0.095976  1.165740  Organic Strawberries
# 145         0.095636  1.161611  Organic Strawberries
# 2788        0.095116  1.155287  Organic Strawberries
# 2569        0.093789  1.139178  Organic Strawberries
# 159         0.093585  1.136695  Organic Strawberries
# 324         0.093406  1.134525  Organic Strawberries
# 871         0.092771  1.126804  Organic Strawberries
# 2950        0.092286  1.120922  Organic Strawberries
# 1331        0.091699  1.113789  Organic Strawberries
# 261         0.091508  1.111469  Organic Strawberries
# 1810        0.090612  1.100584  Organic Strawberries
# 2781        0.089590  1.088177  Organic Strawberries
# 520         0.088747  1.077930  Organic Strawberries
# 1392        0.088400  1.073716  Organic Strawberries
# 904         0.088081  1.069848  Organic Strawberries
# 53          0.087364  1.061140  Organic Strawberries
# 1161        0.087227  1.059467  Organic Strawberries
# 255         0.087209  1.059248  Organic Strawberries
# 182         0.087195  1.059080  Organic Strawberries
# 3269        0.086759  1.053782  Organic Strawberries
# 3341        0.086609  1.051960  Organic Strawberries
# 3325        0.086197  1.046955  Organic Strawberries
# 2036        0.085895  1.043287  Organic Strawberries
# 218         0.085888  1.043208  Organic Strawberries
# 2071        0.085555  1.039165  Organic Strawberries
# 1562        0.085355  1.036738  Organic Strawberries
# 917         0.084759  1.029497  Organic Strawberries
# 822         0.084597  1.027526  Organic Strawberries
# 322         0.084317  1.024128  Organic Strawberries
# 1346        0.084074  1.021175  Organic Strawberries
# 516         0.083788  1.017705  Organic Strawberries
# 3576        0.083768  1.017457  Organic Strawberries
# 2119        0.083717  1.016837  Organic Strawberries
# 3482        0.083271  1.011426  Organic Strawberries
# 1608        0.082694  1.004409  Organic Strawberries
# 3382        0.082647  1.003846  Organic Strawberries
# 2725        0.082353  1.000276  Organic Strawberries
# 2022        0.082345  1.000172  Organic Strawberries
# 3750        0.082285  0.999447  Organic Strawberries
# 1828        0.082026  0.996303  Organic Strawberries
# 2919        0.081631  0.991499  Organic Strawberries
# 2522        0.081403  0.988729  Organic Strawberries
# 1219        0.081182  0.986048  Organic Strawberries
# 3           0.081062  0.984590  Organic Strawberries
# 821         0.080060  0.972422  Organic Strawberries
# 1672        0.079688  0.967906  Organic Strawberries
# 416         0.079555  0.966289  Organic Strawberries
# 20          0.079249  0.962569  Organic Strawberries
# 720         0.079189  0.961840  Organic Strawberries
# 2346        0.079128  0.961096  Organic Strawberries
# 1646        0.079089  0.960625  Organic Strawberries
# 2558        0.078909  0.958442  Organic Strawberries
# 374         0.078397  0.952225  Organic Strawberries
# 1991        0.077978  0.947132  Organic Strawberries
# 1226        0.077263  0.938447  Organic Strawberries
# 2095        0.076905  0.934094  Organic Strawberries
# 637         0.076846  0.933382  Organic Strawberries
# 481         0.076007  0.923195  Organic Strawberries
# 486         0.075553  0.917681  Organic Strawberries
# 2676        0.074981  0.910728  Organic Strawberries
# 413         0.074750  0.907929  Organic Strawberries
# 715         0.074454  0.904327  Organic Strawberries
# 168         0.074287  0.902301  Organic Strawberries
# 134         0.074181  0.901006  Organic Strawberries
# 331         0.074152  0.900655  Organic Strawberries
# 2729        0.073592  0.893861  Organic Strawberries
# 150         0.072947  0.886026  Organic Strawberries
# 3165        0.072657  0.882495  Organic Strawberries
# 3352        0.072484  0.880398  Organic Strawberries
# 1659        0.072250  0.877560  Organic Strawberries
# 3434        0.071909  0.873416  Organic Strawberries
# 2800        0.071846  0.872656  Organic Strawberries
# 664         0.071279  0.865763  Organic Strawberries
# 1390        0.071255  0.865475  Organic Strawberries
# 1549        0.071156  0.864268  Organic Strawberries
# 876         0.071093  0.863500  Organic Strawberries
# 562         0.070627  0.857841  Organic Strawberries
# 687         0.070179  0.852402  Organic Strawberries
# 3189        0.070073  0.851121  Organic Strawberries
# 2149        0.069756  0.847262  Organic Strawberries
# 1287        0.069566  0.844958  Organic Strawberries
# 502         0.068893  0.836783  Organic Strawberries
# 104         0.068742  0.834951  Organic Strawberries
# 3394        0.068577  0.832947  Organic Strawberries
# 49          0.068495  0.831953  Organic Strawberries
# 583         0.066912  0.812724  Organic Strawberries
# 2645        0.064001  0.777365  Organic Strawberries
# 3419        0.063685  0.773526  Organic Strawberries
# 1572        0.063338  0.769316  Organic Strawberries
# 1187        0.063245  0.768184  Organic Strawberries
# 2844        0.063217  0.767847  Organic Strawberries
# 312         0.062847  0.763353  Organic Strawberries
# 2312        0.062788  0.762626  Organic Strawberries
# 3094        0.062388  0.757778  Organic Strawberries
# 3774        0.062062  0.753814  Organic Strawberries
# 951         0.061936  0.752285  Organic Strawberries
# 3380        0.061657  0.748889  Organic Strawberries
# 1895        0.061269  0.744178  Organic Strawberries
# 1224        0.061236  0.743779  Organic Strawberries
# 586         0.060739  0.737739  Organic Strawberries
# 3106        0.060126  0.730298  Organic Strawberries
# 3655        0.060062  0.729525  Organic Strawberries
# 725         0.059292  0.720166  Organic Strawberries
# 2379        0.058710  0.713096  Organic Strawberries
# 5           0.058709  0.713092  Organic Strawberries
# 1151        0.058612  0.711904  Organic Strawberries
# 1403        0.058526  0.710864  Organic Strawberries
# 1344        0.058362  0.708877  Organic Strawberries
# 3451        0.058310  0.708235  Organic Strawberries
# 1135        0.058267  0.707719  Organic Strawberries
# 3705        0.058194  0.706828  Organic Strawberries
# 1196        0.055804  0.677800  Organic Strawberries
# 138         0.054403  0.660786  Organic Strawberries
# 1748        0.054161  0.657852  Organic Strawberries
# 1539        0.053961  0.655423  Organic Strawberries
# 534         0.053920  0.654925  Organic Strawberries
# 2838        0.053737  0.652701  Organic Strawberries
# 754         0.053014  0.643912  Organic Strawberries
# 2241        0.051056  0.620134  Organic Strawberries
# 2986        0.050523  0.613659  Organic Strawberries
# 2405        0.048501  0.589105  Organic Strawberries
# 976         0.048041  0.583510  Organic Strawberries
# 2484        0.045047  0.547149  Organic Strawberries
# 2805        0.044603  0.541758  Organic Strawberries
# 1865        0.043147  0.524072  Organic Strawberries
#
#                                           productB_name
# 1854                                  Organic Nectarine
# 835                              Organic Yellow Peaches
# 1129                      Organic Green Seedless Grapes
# 2292                                 Organic AppleApple
# 1754                      Organic Large Green Asparagus
# 1749  YoKids Squeezers Organic Low-Fat Yogurt, Straw...
# 285                                        Organic Kiwi
# 554                               Organic Bartlett Pear
# 25                                  Organic Raspberries
# 3153                                      Bing Cherries
# 1350                                         Cantaloupe
# 2404                              Organic Beef Hot Dogs
# 2965                       Large Yellow Flesh Nectarine
# 52                                  Organic Blueberries
# 242                         Organic Whole String Cheese
# 1137                      Organic Roasted Turkey Breast
# 2668                        Organic Snipped Green Beans
# 2395                                         White Corn
# 3011                             Original Veggie Straws
# 437                               Organic D'Anjou Pears
# 2595                        Organic Shredded Mozzarella
# 1683                         Organic Hothouse Cucumbers
# 307                             Organic Red Bell Pepper
# 2798                    Organic American Cheese Singles
# 1093                               Whipped Cream Cheese
# 735                                    Organic Broccoli
# 933   Organic Sticks Low Moisture Part Skim Mozzarel...
# 2790                            Organic Broccoli Crowns
# 135                                    Organic Cucumber
# 1705                                  Watermelon Chunks
# 1873                                Organic Bell Pepper
# 171                Organic Large Extra Fancy Fuji Apple
# 295                                Organic Blackberries
# 3144                       Organic Creamy Peanut Butter
# 963                            Organic Reduced Fat Milk
# 831                          Grape White/Green Seedless
# 3142                  Chicken & Maple Breakfast Sausage
# 3728  Air Chilled Organic Boneless Skinless Chicken ...
# 14                                 Organic Hass Avocado
# 145                            Apple Honeycrisp Organic
# 2788                                Organic Frozen Peas
# 2569                                  Organic Bosc Pear
# 159                              Organic Grape Tomatoes
# 324                              Organic Tomato Cluster
# 871         Organic Grade A Free Range Large Brown Eggs
# 2950                           Milk, Organic, Vitamin D
# 1331        Organic Large Brown Grade AA Cage Free Eggs
# 261                                 Organic Gala Apples
# 1810                          Organic Red Radish, Bunch
# 2781                            Organic Unsalted Butter
# 520                   Organic Peeled Whole Baby Carrots
# 1392                              Organic Russet Potato
# 904                                Uncured Genoa Salami
# 53                                   Organic Whole Milk
# 1161                                  Shredded Parmesan
# 255                                Organic Baby Carrots
# 182                                       Organic Lemon
# 3269                                       Organic Yams
# 3341                                     Marinara Sauce
# 3325                  Organic Old Fashioned Rolled Oats
# 2036                       Shredded Mild Cheddar Cheese
# 218                                 Seedless Red Grapes
# 2071                              Organic Fat Free Milk
# 1562                         Organic Whole Strawberries
# 917                                Organic Navel Orange
# 822                                     Grated Parmesan
# 322                                     Original Hummus
# 1346                            Organic Romaine Lettuce
# 516                          Organic Granny Smith Apple
# 3576                                       Organic Mint
# 2119                               Ground Turkey Breast
# 3482                           Organic Shredded Carrots
# 1608                              Organic Baby Broccoli
# 3382                Uncured Hickory Smoked Sunday Bacon
# 2725                                    Organic Romaine
# 2022                                       Organic Milk
# 3750                       Organic Baby Rainbow Carrots
# 1828                    Frozen Organic Wild Blueberries
# 2919                 Organic Bread with 21 Whole Grains
# 2522               Lightly Salted Baked Snap Pea Crisps
# 1219                                Organic Black Beans
# 3                                Bag of Organic Bananas
# 821                         Organic Reduced Fat 2% Milk
# 1672                               Feta Cheese Crumbles
# 416                          Organic Small Bunch Celery
# 20                                 Organic Baby Spinach
# 720                   Organic Garnet Sweet Potato (Yam)
# 2346                                 Organic Sour Cream
# 1646                           Organic Broccoli Florets
# 2558                  Organic Large Grade AA Brown Eggs
# 374                                   Fresh Cauliflower
# 1991  Total 2% with Strawberry Lowfat Greek Strained...
# 1226                                   Clementines, Bag
# 2095                                Organic Roma Tomato
# 637                     Organic Unsweetened Almond Milk
# 481                                           Asparagus
# 486                               Michigan Organic Kale
# 2676                                    Red Raspberries
# 413                                Organic Baby Arugula
# 715                                   Green Bell Pepper
# 168                                    Organic Zucchini
# 134                                Organic Yellow Onion
# 331                                    Honeycrisp Apple
# 2729                        Total Greek Strained Yogurt
# 150                                      Organic Garlic
# 3165                       Organic Heavy Whipping Cream
# 3352                              Organic Celery Hearts
# 1659                               Organic Carrot Bunch
# 3434                               Organic White Onions
# 2800                                      Organic Basil
# 664                       Organic Italian Parsley Bunch
# 1390                                Large Alfresco Eggs
# 1549                             100% Raw Coconut Water
# 876                                 Organic Ginger Root
# 562                                   Organic Red Onion
# 687                              100% Whole Wheat Bread
# 3189                                 Yellow Bell Pepper
# 2149                                 Organic Spring Mix
# 1287                   Organic Lacinato (Dinosaur) Kale
# 502                                             Carrots
# 104                                               Limes
# 3394                                   Pineapple Chunks
# 49                                      Organic Avocado
# 583                                    Organic Cilantro
# 2645                    Italian Sparkling Mineral Water
# 3419                                 Honey Nut Cheerios
# 1572                                     Broccoli Crown
# 1187                             Unsweetened Almondmilk
# 2844                             Organic Garbanzo Beans
# 312                                      Cucumber Kirby
# 2312                                  Pure Irish Butter
# 3094                            Organic Extra Firm Tofu
# 3774                                     Romaine Hearts
# 951                                         Raspberries
# 3380                         100% Recycled Paper Towels
# 1895                                 Orange Bell Pepper
# 1224                  Boneless Skinless Chicken Breasts
# 586                                 Organic Half & Half
# 3106                               Sharp Cheddar Cheese
# 3655                               Organic Coconut Milk
# 725                                         Half & Half
# 2379                                    Unsalted Butter
# 5                                                Banana
# 1151                                    Red Vine Tomato
# 1403                                 Small Hass Avocado
# 1344                             Extra Virgin Olive Oil
# 3451                                        Green Beans
# 1135                                        Red Peppers
# 3705                          No Salt Added Black Beans
# 1196                                        Blueberries
# 138                                         Large Lemon
# 1748                               Lime Sparkling Water
# 1539                                      Hass Avocados
# 534                                  Organic Fuji Apple
# 2838                                     Bartlett Pears
# 754                          Sparkling Water Grapefruit
# 2241                                   Jalapeno Peppers
# 2986                                             Garlic
# 2405                                          Red Onion
# 976                                       Yellow Onions
# 2484                                   Bunched Cilantro
# 2805                    Sparkling Natural Mineral Water
# 1865                                       Spring Water

# %%
top_itemsets_df[top_itemsets_df['lift'].between(0.99, 1.01, inclusive=False)].head()
# Out:
# C:\Users\HEN1\AppData\Local\Temp/ipykernel_7900/2209779414.py:1: FutureWarning: Boolean inputs to the `inclusive` argument are deprecated infavour of `both` or `neither`.
#   top_itemsets_df[top_itemsets_df['lift'].between(0.99, 1.01, inclusive=False)].head()
#      itemA_id  itemB_id  supportAB  supportA  supportB  confidenceAtoB  \
# 12      24852     16797   0.006566  0.146993  0.044466        0.044669
# 65      21903     47626   0.003585  0.075251  0.047485        0.047640
# 152     13176     44359   0.002488  0.118030  0.021180        0.021075
# 208     24852     25890   0.002282  0.146993  0.015640        0.015524
# 228     22035     13176   0.002192  0.018562  0.118030        0.118071
#
#      confidenceBtoA      lift                productA_name  \
# 12         0.147666  1.004576                       Banana
# 65         0.075496  1.003263         Organic Baby Spinach
# 152        0.117446  0.995054       Bag of Organic Bananas
# 208        0.145900  0.992562                       Banana
# 228        0.018569  1.000351  Organic Whole String Cheese
#
#                          productB_name
# 12                        Strawberries
# 65                         Large Lemon
# 152         Organic Small Bunch Celery
# 208  Boneless Skinless Chicken Breasts
# 228             Bag of Organic Bananas

# %%
top_itemsets_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 55137021 entries, 0 to 55137020
# Data columns (total 8 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   itemA_id        int64
#  1   itemB_id        int64
#  2   supportAB       float64
#  3   supportA        float64
#  4   supportB        float64
#  5   confidenceAtoB  float64
#  6   confidenceBtoA  float64
#  7   lift            float64
# dtypes: float64(6), int64(2)
# memory usage: 3.7 GB

# %%
top_itemsets_df.supportAB.max()
# Out:
# 0.009735995874177339

# %% [markdown]
# # Insights And Findings

# %% [markdown]
# 1. The association rule between "Bag of Organic Bananas" and "Organic Hass Avocado" has a high support (0.009736) and confidence (0.082488), indicating that these two items are frequently purchased together. The lift value (1.241609) suggests that the occurrence of "Organic Hass Avocado" and the occurrence of "Bag of Organic Bananas" are strong correlated. This is a pretty straight forward finding, because people who are willing to buy organic banana are possible to buy organic avocado as carbohydrates for health reasons.

# %% [markdown]
# 2. The association rule between "Organic Strawberries" and "Banana" has a relatively high support (0.008630) and confidence (0.104820). This suggests that these two items are often bought together by customers. The lift value (0.713092) indicates that the occurrence of "Banana" is slightly reduced when "Organic Strawberries" is purchased. From the data above, we can tell that people who buy organic strawberries are more willing to buy healthy food like natural or organic food, and not that willing to buy groceries like garlic.

# %% [markdown]
# 3. The association rule between "Banana" and "Strawberries" has a moderate support (0.006566) and confidence (0.044669). This indicates that there is a moderate association between these two items. The lift value (1.004576) close to 1 suggests that the occurrence of "Strawberries" has minimal impact on the likelihood of purchasing "Banana". The popular itemsets like "Organic Baby Spinach" and "Large Lemon", "Bags of Organic Bananas" and "Organic Small Bunch Celery", "Bag of Organic Bananas" and "Organic Small Bunch Celery", "Banana" and "Boneless Skinless Chicken Breasts", "Organic Whole String Cheese" and "Bag of Organic Bananas" are under the same situation. It implies that these items in itemsets are independent to each other. It is pretty hard to use common sense to explain this phenomenon, but we can suggest that the target customers for product A and product B are different.

# %% [markdown]
# 4. The association rule between "Organic Hass Avocado" and "Organic Raspberries" has a relatively low support (0.004014) and confidence (0.060417). This suggests that these two items are not frequently purchased together. The lift value (1.417158) indicates that the occurrence of "Organic Raspberries" increases by 41.72% when "Organic Hass Avocado" is also purchased. We can use this finding to boost our sales by creating a "BUY X GET Y" discount for these two products.

# %% [markdown]
# # Limitations

# %% [markdown]
# 1. Due to the dataset is pretty large, this notebook only focus on itemset with 2 items. There are still many relationship worth to explore.

# %% [markdown]
# 2. The Apriori algorithm focuses on identifying frequent itemsets but does not consider the order in which items appear within a transaction. It may overlook important sequential patterns or temporal dependencies present in the data.

# %% [markdown]
# 3. Association rules generated by the Apriori algorithm provide information about co-occurrence patterns but lack insights into the strength or causality of relationships between items. It does not capture the complex interactions and dependencies that may exist between items.
